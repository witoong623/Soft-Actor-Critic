# %%
import sys
sys.path.append('C:\\Users\\Hasegawa\\Desktop\\AIT Note\\Thesis\\thesis-code\\Soft-Actor-Critic')

# %%
import numpy as np
import torchvision.transforms as T
import matplotlib.pyplot as plt

from PIL import Image
from common.network import ConvVAE

# %%
model = ConvVAE((270, 480), latent_size=512)

# %%
model.load_model('epoch(10)-loss(+2.294E+05).pkl')
# Out:
# <All keys matched successfully>

# %%
to_tensor = T.ToTensor()

# %%
test_image = Image.open('carla_image_43627.jpeg')

# %%
test_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x270 at 0x1C5EEF63EB0>

# %%
output = model(to_tensor(test_image).unsqueeze(dim=0))

# %%
out_np_array = output[0].squeeze(dim=0).detach().numpy()

# %%
output_image = Image.fromarray((out_np_array.transpose(1, 2, 0) * 255).astype('uint8'))

# %%
output_image
# Out:
# <PIL.Image.Image image mode=RGB size=480x270 at 0x1C5D95540D0>
